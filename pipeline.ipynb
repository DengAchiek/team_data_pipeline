# %%
pip install jupyterlab-git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.3/613.3 kB 4.1 MB/s  0:00:00? eta -:--:--
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 21.3 MB/s  0:00:000.5 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [jupyterlab-git] 8/10 [nbdime]lab-git-core]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importation of libraries

import pandas as pd
import numpy as np

# loading and reading data 
data = pd.read_csv('/Users/dengachiek/Downloads/student-lifestyle-and-stress-dataset.csv')
data.head()
# Out:
#   Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0       school     6.868702     1.711722            3.176942         NaN
# 1       school     8.519088     3.251084            3.880787   93.978465
# 2      college     4.498770     6.306885            2.936172   64.421253
# 3       school     8.591223     2.384922            5.222832   81.868960
# 4      college     5.329293     9.345179            7.815869   85.847982
#
#    Exam_Pressure  Family_Support  Month  Stress_Level
# 0            8.0             7.0    2.0             1
# 1            6.0             4.0    3.0             1
# 2            7.0             1.0   12.0             1
# 3            2.0             7.0    7.0             0
# 4            5.0             6.0   10.0             1
